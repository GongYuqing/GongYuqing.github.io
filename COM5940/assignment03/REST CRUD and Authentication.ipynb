# %% [markdown]
# <center><h1>WordPress RESTful API CRUD Operations</center></h1>

# %%
import requests
import pandas as pd
from io import StringIO
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.text = StringIO()
    def handle_data(self, d):
        self.text.write(d)
    def get_data(self):
        return self.text.getvalue()
    
def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()
    

user = 'admin'
url = 'http://localhost/wordpress/wp-json/wp/v2/bands'
r = requests.get(url)
print("Status Code:",r.status_code)
r_list = r.json()

dataset = []
dict = {}
for i in r_list:    
     # print(i['id'])
     dict['id'] = i['id']   
     title = i['title']
     content = i['content']
     for k, v in title.items():
        # print(v)
        dict['title'] = v
     for k, v in content.items():
        # print(v)
        if k == 'rendered':
            dict['content'] = strip_tags(v)
     dataset.append(dict.copy())
print(dataset)
print('**************************************************************************')
print('\n')
print(pd.DataFrame(dataset))
# Out:
# Status Code: 200
# [{'id': 26, 'title': '马赛克', 'content': ''}, {'id': 24, 'title': '木马', 'content': ''}, {'id': 22, 'title': '重塑雕像的权利', 'content': ''}, {'id': 18, 'title': '大波浪', 'content': ''}]
# **************************************************************************
#
#
#    id    title content
# 0  26      马赛克
# 1  24       木马
# 2  22  重塑雕像的权利
# 3  18      大波浪

# %% [markdown]
# <center><h1>WordPress RESTful API GET(Retrieve) Operation (Local Mode)</h1></center>

# %%
import requests
import pandas as pd
from io import StringIO
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.text = StringIO()
    def handle_data(self, d):
        self.text.write(d)
    def get_data(self):
        return self.text.getvalue()
    
def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()
    

user = 'admin'
url = 'http://localhost/wordpress/wp-json/wp/v2/bands'
r = requests.get(url)
print("Status Code:",r.status_code)
r_list = r.json()

dataset = []
dict = {}
for i in r_list:    
     # print(i['id'])
     dict['id'] = i['id']   
     title = i['title']
     content = i['content']
     for k, v in title.items():
        # print(v)
        dict['title'] = v
     for k, v in content.items():
        # print(v)
        if k == 'rendered':
            dict['content'] = strip_tags(v)
     dataset.append(dict.copy())
print(dataset)
print('**************************************************************************')
print('\n')
print(pd.DataFrame(dataset))
# Out:
# Status Code: 200
# [{'id': 26, 'title': '马赛克', 'content': ''}, {'id': 24, 'title': '木马', 'content': ''}, {'id': 22, 'title': '重塑雕像的权利', 'content': ''}, {'id': 18, 'title': '大波浪', 'content': ''}]
# **************************************************************************
#
#
#    id    title content
# 0  26      马赛克
# 1  24       木马
# 2  22  重塑雕像的权利
# 3  18      大波浪

# %% [markdown]
# <h1 style="color:red;"><center>Basic Auth</center></h1>

# %% [markdown]
# <center><h1>WordPress RESTful API POST(Create) Operation (Basic Auth)</h1></center>

# %%
from flask import Flask, request, make_response
import base64
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
from io import StringIO
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.text = StringIO()
    def handle_data(self, d):
        self.text.write(d)
    def get_data(self):
        return self.text.getvalue()
    
def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()
    
title = 'joyside'
content = 'Another band!'
status = 'publish'

data =  {
    "title": title,
    "content": content,
    "status": status
    }

url = 'http://localhost/wordpress/wp-json/wp/v2/bands'
r=requests.post(url, 
                headers={"Authorization": "Basic Y29tNTk0MC1neXE6OTgwNDE5Z3lx"},
                data=data)

print("Status Code:",r.status_code)
        
user = 'admin'
url = 'http://localhost/wordpress/wp-json/wp/v2/bands'
r = requests.get(url)
print("Status Code:",r.status_code)
r_list = r.json()

dataset = []
dict = {}
for i in r_list:    
     # print(i['id'])
     dict['id'] = i['id']   
     title = i['title']
     content = i['content']
     for k, v in title.items():
        # print(v)
        dict['title'] = v
     for k, v in content.items():
        # print(v)
        if k == 'rendered':
            dict['content'] = strip_tags(v)
     dataset.append(dict.copy())
print(dataset)
print('**************************************************************************')
print('\n')
print(pd.DataFrame(dataset))
# Out:
# Status Code: 201
# Status Code: 200
# [{'id': 52, 'title': 'joyside', 'content': 'Another band!\n'}, {'id': 26, 'title': '马赛克', 'content': ''}, {'id': 24, 'title': '木马', 'content': ''}, {'id': 22, 'title': '重塑雕像的权利', 'content': ''}, {'id': 18, 'title': '大波浪', 'content': ''}]
# **************************************************************************
#
#
#    id    title          content
# 0  52  joyside  Another band!\n
# 1  26      马赛克
# 2  24       木马
# 3  22  重塑雕像的权利
# 4  18      大波浪

# %% [markdown]
# <center><h1>WordPress RESTful API PUT(Update) Operation (Basic Auth)</h1></center>

# %%
from flask import Flask, request, make_response
import base64
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
from io import StringIO
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.text = StringIO()
    def handle_data(self, d):
        self.text.write(d)
    def get_data(self):
        return self.text.getvalue()
    
def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()
    
title = 'joyside'
content = 'Another good band!'
status = 'publish'

data =  {
    "title": title,
    "content": content,
    "status": status
    }

url = 'http://localhost/wordpress/wp-json/wp/v2/bands/51' # WP post ID 292
r=requests.put(url, 
                headers={"Authorization": "Basic Y29tNTk0MC1neXE6OTgwNDE5Z3lx"},
                data=data)

print("Status Code:",r.status_code)
        
user = 'admin'
url = 'http://localhost/wordpress/wp-json/wp/v2/bands'
r = requests.get(url)
print("Status Code:",r.status_code)
r_list = r.json()

dataset = []
dict = {}
for i in r_list:    
     # print(i['id'])
     dict['id'] = i['id']   
     title = i['title']
     content = i['content']
     for k, v in title.items():
        # print(v)
        dict['title'] = v
     for k, v in content.items():
        # print(v)
        if k == 'rendered':
            dict['content'] = strip_tags(v)
     dataset.append(dict.copy())
print(dataset)
print('**************************************************************************')
print('\n')
print(pd.DataFrame(dataset))
# Out:
# Status Code: 200
# Status Code: 200
# [{'id': 51, 'title': 'joyside', 'content': 'Another good band!\n'}, {'id': 26, 'title': '马赛克', 'content': ''}, {'id': 24, 'title': '木马', 'content': ''}, {'id': 22, 'title': '重塑雕像的权利', 'content': ''}, {'id': 18, 'title': '大波浪', 'content': ''}]
# **************************************************************************
#
#
#    id    title               content
# 0  51  joyside  Another good band!\n
# 1  26      马赛克
# 2  24       木马
# 3  22  重塑雕像的权利
# 4  18      大波浪

# %% [markdown]
# <center><h1>WordPress RESTful API DELETE(Delete) Operation (Basic Auth)</h1></center>

# %%
from flask import Flask, request, make_response
import base64
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
from io import StringIO
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.text = StringIO()
    def handle_data(self, d):
        self.text.write(d)
    def get_data(self):
        return self.text.getvalue()
    
def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

url = 'http://localhost/wordpress/wp-json/wp/v2/bands/51' # WP post ID 292
r=requests.delete(url, 
            headers = {'Authorization': 'Basic Y29tNTk0MC1neXE6OTgwNDE5Z3lx', 'Content-Type': 'application/x-www-form-urlencoded'})

print("Status Code:",r.status_code)
        
user = 'admin'
url = 'http://localhost/wordpress/wp-json/wp/v2/bands'
r = requests.get(url)
print("Status Code:",r.status_code)
r_list = r.json()

dataset = []
dict = {}
for i in r_list:    
     # print(i['id'])
     dict['id'] = i['id']   
     title = i['title']
     content = i['content']
     for k, v in title.items():
        # print(v)
        dict['title'] = v
     for k, v in content.items():
        # print(v)
        if k == 'rendered':
            dict['content'] = strip_tags(v)
     dataset.append(dict.copy())
print(dataset)
print('**************************************************************************')
print('\n')
print(pd.DataFrame(dataset))
# Out:
# Status Code: 200
# Status Code: 200
# [{'id': 26, 'title': '马赛克', 'content': ''}, {'id': 24, 'title': '木马', 'content': ''}, {'id': 22, 'title': '重塑雕像的权利', 'content': ''}, {'id': 18, 'title': '大波浪', 'content': ''}]
# **************************************************************************
#
#
#    id    title content
# 0  26      马赛克
# 1  24       木马
# 2  22  重塑雕像的权利
# 3  18      大波浪
